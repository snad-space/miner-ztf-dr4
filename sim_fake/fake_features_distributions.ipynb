# %%
import os
import sys
from itertools import chain
from functools import reduce

import light_curve as lc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from validutils_zwad.read_data import read_data

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Load binary feature files from simulation_fake_features.ipynb

# %%
model_list = ['SNIa', 'TDE', 'SNIbc', 'SLSN-I', 'SNII-NMF']
model_num_list = [90, 64, 62, 60, 42]

# %%
df_list = []
for model, model_num in zip(model_list, model_num_list):
    oid = np.memmap(f'./output/oid_sim_{model_num}_{model}.dat', mode='r', dtype=np.uint64)
    names = open(f'./output/feature_sim_{model_num}_{model}.name').read().split()
    dtype = [(name, np.float32) for name in names]
    x = np.memmap(f'./output/feature_sim_{model_num}_{model}.dat', mode='r', dtype=np.float32, shape=(oid.size, 106))
    

    df = pd.DataFrame(x, columns=names)
    df_list.append(df)

# %%
df_90, df_64, df_62, df_60, df_42 = df_list

if not os.path.exists(f'./features_distributions'):
    os.makedirs(f'./features_distributions')

for feature in names:
    fix, ax = plt.subplots(figsize=(6,4))
    for df_model, model in zip(df_list, model_list):
        ax.hist(df_model[feature], bins=np.linspace(min(df_model[feature]), max(df_model[feature]), 20),
                label=model, histtype = 'step', alpha=0.8, linewidth=2)
        ax.set_xlabel(feature)
        ax.set_yscale('log')
        ax.legend()
        plt.savefig(f'./features_distributions/{feature}.png', dpi=300, bbox_inches='tight')
    plt.clf()
# Out:
# /var/folders/6b/_lh6wycs3hs640n946l0wl_r0000gn/T/ipykernel_30121/641811693.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fix, ax = plt.subplots(figsize=(6,4))

# %%
passbands=('g', 'r',)
min_obs_count = 100

def threshold_nobs(pklfilepath, passbands, min_obs_count):
    X_sim, y_sim = read_data(pklfilepath)
    X_sim_reduced = X_sim[reduce(lambda a, b: a & b, (X_sim['mjd_%s' %pb ].map(len) >= min_obs_count for pb in passbands))]
    
    return X_sim_reduced

def replace_magn_with_flux(s):
    if 'magnitude' in s:
        return s.replace('magnitudes', 'fluxes').replace('magnitude', 'flux')
    return f'{s} for flux light curve'


def create_base_features_class(
        magn_extractor,
        flux_extractor,
        passbands=passbands, 
        min_obs_count=min_obs_count,  
        cls_name='BaseFeatures'
    ):
    feature_names = ([f'{name}_magn' for name in magn_extractor.names]
                     + [f'{name}_flux' for name in flux_extractor.names])
    property_names = {band: [f'{name}_{band}'.lower()
                             for name in feature_names]
                      for band in passbands}
    feature_descriptions = (magn_extractor.descriptions 
                            + [replace_magn_with_flux(desc) for desc in flux_extractor.descriptions])
    property_descriptions = {band: [f'{band}-band {desc}'
                             for desc in feature_descriptions]
                      for band in passbands}
    
    features_count = len(feature_names)
    
    return type(
        cls_name,
        (object,),
        {
            '_passbands': passbands,
            'min_obs_count': min_obs_count,
            'magn_extractor': magn_extractor,
            'flux_extractor': flux_extractor,
            'property_names': property_names,
        }
    )


# TODO: add PERIODOGRAM features!
MAGN_EXTRACTOR = lc.Extractor(
    lc.Amplitude(),
    lc.AndersonDarlingNormal(),
    lc.BeyondNStd(1.0),
    lc.BeyondNStd(2.0),
    lc.Cusum(),
    lc.EtaE(),
    lc.InterPercentileRange(0.02),
    lc.InterPercentileRange(0.1),
    lc.InterPercentileRange(0.25),
    lc.Kurtosis(),
    lc.LinearFit(),
    lc.LinearTrend(),
    lc.MagnitudePercentageRatio(0.4, 0.05),
    lc.MagnitudePercentageRatio(0.2, 0.05),
    lc.MaximumSlope(),
    lc.Mean(),
    lc.MedianAbsoluteDeviation(),
    lc.MedianBufferRangePercentage(0.1),
    lc.MedianBufferRangePercentage(0.2),
    lc.PercentAmplitude(),
    lc.PercentDifferenceMagnitudePercentile(0.05),
    lc.PercentDifferenceMagnitudePercentile(0.1),
    lc.Periodogram(
        peaks=5,
        resolution=10.0,
        max_freq_factor=2.0,
        nyquist='average',
        fast=True,
        features=(
            lc.Amplitude(),
            lc.BeyondNStd(2.0),
            lc.BeyondNStd(3.0),
            lc.StandardDeviation(),
        ),
    ),
    lc.ReducedChi2(),
    lc.Skew(),
    lc.StandardDeviation(),
    lc.StetsonK(),
    lc.WeightedMean(),
)


FLUX_EXTRACTOR = lc.Extractor(
    lc.AndersonDarlingNormal(),
    lc.Cusum(),
    lc.EtaE(),
    lc.ExcessVariance(),
    lc.Kurtosis(),
    lc.MeanVariance(),
    lc.ReducedChi2(),
    lc.Skew(),
    lc.StetsonK(),
)

features_list = []

class Features(create_base_features_class(MAGN_EXTRACTOR, FLUX_EXTRACTOR)):

    def run(self):
        #t_list, m_list, merr_list, flux_list, fluxerr_list = [], [], [], [], []
        for band, names in self.property_names.items():
            print(band)
            t_list, m_list, merr_list, flux_list, fluxerr_list = [], [], [], [], []
            for snid, mjd, mag, magerr in zip(X['snid'], 
                                              X['mjd_%s' %band], 
                                              X['mag_%s' %band], 
                                              X['magerr_%s' %band]):

                t = mjd
                m = mag.astype('float64')
                merr = magerr.astype('float64')
                flux = np.power(10.0, -0.4 * m)
                fluxerr = 0.5 * flux * (np.power(10.0, 0.4 * merr) - np.power(10.0, -0.4 * merr))
                
                print('append props to lists...')
                t_list.append(t)
                m_list.append(m)
                merr_list.append(merr) 
                flux_list.append(flux)
                fluxerr_list.append(fluxerr)

                magn_features = self.magn_extractor(
                    t,
                    m,
                    merr,
                    sorted=None,
                    fill_value=None,
                )
                flux_features = self.flux_extractor(
                    t,
                    flux,
                    fluxerr,
                    sorted=None,
                    fill_value=None,
                )
                
                # After successfully calculating features, set sim ID and feature values
                features_dict = {}
                features_dict['sim_id'] = int(str(model_num)+str(snid))
                for name, value in zip(names, chain(magn_features, flux_features)):
                    features_dict[name] = value
                features_list.append(features_dict)
                
        return features_list, t_list, m_list, merr_list, flux_list, fluxerr_list

# %%
pklfilepath_list=['./ztf_dr3_sim_data/ZTF_SIMS_ALLMODELS_3RD_RUN/PALEO_ZTF_MODEL90_SNIa-SALT2.pkl.gz',
                  './ztf_dr3_sim_data/ZTF_SIMS_ALLMODELS_3RD_RUN/PALEO_ZTF_MODEL64_TDE.pkl.gz',
                  './ztf_dr3_sim_data/ZTF_SIMS_ALLMODELS_3RD_RUN/PALEO_ZTF_MODEL62_SNIbc-MOSFIT.pkl.gz',
                  './ztf_dr3_sim_data/ZTF_SIMS_ALLMODELS_3RD_RUN/PALEO_ZTF_MODEL60_SLSN-I.pkl.gz',
                  './ztf_dr3_sim_data/ZTF_SIMS_ALLMODELS_3RD_RUN/PALEO_ZTF_MODEL42_SNII-NMF.pkl.gz',
                  ]

t_list_all, m_list_all, merr_list_all, flux_list_all, fluxerr_list_all = [],[],[],[],[]

for pklfilepath, model, model_num in zip(pklfilepath_list, model_list, model_num_list):

    X = threshold_nobs(pklfilepath=pklfilepath, 
                  passbands=passbands,
                  min_obs_count=min_obs_count)
    
    calc = Features()
    print(model, model_num)
    features_list, t_list, m_list, merr_list, flux_list, fluxerr_list = calc.run()
    t_list_all.append(np.hstack(t_list))
    m_list_all.append(np.hstack(m_list))
    merr_list_all.append(np.hstack(merr_list))
    flux_list_all.append(np.hstack(flux_list))
    fluxerr_list_all.append(np.hstack(fluxerr_list))
    
    print(len(t_list))
    
    features_list.clear()
    t_list.clear()
    m_list.clear()
    merr_list.clear()
    flux_list.clear()
    fluxerr_list.clear()
# Out:
# SNIa 90
# g
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# ...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# append props to lists...
# 3936

# %%
len(t_list_all[4]) #WHY IS THIS NUMBER SO BIG?
# Out:
# 692423

# %%
692423/30000
# Out:
# 23.080766666666666

# %%
len(t_list_all[0])
# Out:
# 598178

# %%
# TO DO: check numbers. Not quite right... plot per band

# %%
if not os.path.exists(f'./features_distributions'):
    os.makedirs(f'./features_distributions')
    
prop_list = ['t', 'm', 'merr', 'flux', 'fluxerr']
list_all = [t_list_all, m_list_all, merr_list_all, flux_list_all, fluxerr_list_all]

for prop, l_all in zip(prop_list, list_all):
    fix, ax = plt.subplots(figsize=(6,4))
    for (idx, model) in enumerate(model_list):
        ax.hist(l_all[idx], bins=np.linspace(min(l_all[idx]), max(l_all[idx]), 20),
                label=model, histtype = 'step', alpha=0.8, linewidth=2)
        ax.set_xlabel(prop)
        ax.set_yscale('log')
        ax.legend()
        plt.savefig(f'./features_distributions/{prop}.png', dpi=300, bbox_inches='tight')
